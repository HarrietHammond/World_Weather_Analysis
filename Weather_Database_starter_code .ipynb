# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import pandas as pd
import numpy as np
import requests 
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 768

# %%
# Create a list for holding the cities.
cities = []

# Use a for loop to identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_current_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tateyama
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | mahebourg
# Processing Record 8 of Set 1 | port-cartier
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | kalmunai
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | bokspits
# City not found. Skipping...
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | omboue
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | morros
# Processing Record 22 of Set 1 | ilulissat
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | clyde river
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | saint-augustin
# Processing Record 28 of Set 1 | beloha
# Processing Record 29 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 30 of Set 1 | burns lake
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | hohhot
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | caravelas
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 1 | kutum
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | santa rosa
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | clemencia
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | nantucket
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | carnot
# Processing Record 48 of Set 1 | alofi
# Processing Record 49 of Set 1 | avera
# Processing Record 50 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 2 | ketchikan
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | rikitea
# Processing Record 4 of Set 2 | udachnyy
# Processing Record 5 of Set 2 | indianola
# Processing Record 6 of Set 2 | westport
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | nago
# Processing Record 9 of Set 2 | ostrowiec swietokrzyski
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | ribeira grande
# Processing Record 12 of Set 2 | pilar
# Processing Record 13 of Set 2 | chuy
# Processing Record 14 of Set 2 | saint george
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | kumluca
# Processing Record 17 of Set 2 | itarema
# Processing Record 18 of Set 2 | melbu
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | upernavik
# Processing Record 21 of Set 2 | hasaki
# Processing Record 22 of Set 2 | llanes
# Processing Record 23 of Set 2 | new norfolk
# Processing Record 24 of Set 2 | grand-santi
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | azuaga
# Processing Record 27 of Set 2 | port hedland
# Processing Record 28 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 2 | kaitangata
# Processing Record 30 of Set 2 | ust-maya
# Processing Record 31 of Set 2 | kalaleh
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | vila franca do campo
# Processing Record 34 of Set 2 | maragogi
# Processing Record 35 of Set 2 | touros
# Processing Record 36 of Set 2 | kasongo-lunda
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | chernogolovka
# Processing Record 39 of Set 2 | san cristobal
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | riyadh
# Processing Record 42 of Set 2 | okhotsk
# Processing Record 43 of Set 2 | tambovka
# Processing Record 44 of Set 2 | two rivers
# Processing Record 45 of Set 2 | banda aceh
# Processing Record 46 of Set 2 | chokurdakh
# Processing Record 47 of Set 2 | qujing
# Processing Record 48 of Set 2 | wattegama
# Processing Record 49 of Set 2 | sao filipe
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | kavieng
# Processing Record 3 of Set 3 | eydhafushi
# Processing Record 4 of Set 3 | bodden town
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | arroyo
# Processing Record 7 of Set 3 | ambilobe
# Processing Record 8 of Set 3 | sao jose da coroa grande
# Processing Record 9 of Set 3 | loukisia
# Processing Record 10 of Set 3 | yerbogachen
# Processing Record 11 of Set 3 | poum
# Processing Record 12 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 3 | saint-francois
# Processing Record 14 of Set 3 | talaya
# Processing Record 15 of Set 3 | jalu
# Processing Record 16 of Set 3 | yerofey pavlovich
# Processing Record 17 of Set 3 | hofn
# Processing Record 18 of Set 3 | rongcheng
# Processing Record 19 of Set 3 | tasiilaq
# Processing Record 20 of Set 3 | arraial do cabo
# Processing Record 21 of Set 3 | butia
# Processing Record 22 of Set 3 | zaranj
# Processing Record 23 of Set 3 | liptovsky mikulas
# Processing Record 24 of Set 3 | amahai
# Processing Record 25 of Set 3 | bubaque
# Processing Record 26 of Set 3 | mezen
# Processing Record 27 of Set 3 | dabakala
# Processing Record 28 of Set 3 | victoria
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | laguna
# Processing Record 32 of Set 3 | turukhansk
# Processing Record 33 of Set 3 | saint-georges
# Processing Record 34 of Set 3 | tiksi
# Processing Record 35 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 3 | bethel
# Processing Record 37 of Set 3 | svetlogorsk
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | hyeres
# Processing Record 40 of Set 3 | flinders
# Processing Record 41 of Set 3 | kavaratti
# Processing Record 42 of Set 3 | souillac
# Processing Record 43 of Set 3 | auki
# Processing Record 44 of Set 3 | tuatapere
# Processing Record 45 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 3 | progreso
# Processing Record 47 of Set 3 | kankon
# Processing Record 48 of Set 3 | fort nelson
# Processing Record 49 of Set 3 | vila do maio
# Processing Record 50 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 4 | luderitz
# Processing Record 2 of Set 4 | kahului
# Processing Record 3 of Set 4 | matadi
# Processing Record 4 of Set 4 | lavrentiya
# Processing Record 5 of Set 4 | tomatlan
# Processing Record 6 of Set 4 | waw
# Processing Record 7 of Set 4 | hambantota
# Processing Record 8 of Set 4 | aklavik
# Processing Record 9 of Set 4 | college
# Processing Record 10 of Set 4 | peleduy
# Processing Record 11 of Set 4 | abu road
# Processing Record 12 of Set 4 | linshu
# City not found. Skipping...
# Processing Record 13 of Set 4 | pochutla
# Processing Record 14 of Set 4 | iskateley
# Processing Record 15 of Set 4 | alot
# Processing Record 16 of Set 4 | vuktyl
# Processing Record 17 of Set 4 | north bend
# Processing Record 18 of Set 4 | port hardy
# Processing Record 19 of Set 4 | nikolskoye
# Processing Record 20 of Set 4 | sun city west
# Processing Record 21 of Set 4 | egvekinot
# Processing Record 22 of Set 4 | solhan
# Processing Record 23 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 4 | grants
# Processing Record 25 of Set 4 | tanete
# Processing Record 26 of Set 4 | mikhaylovka
# Processing Record 27 of Set 4 | sundby
# Processing Record 28 of Set 4 | lichinga
# Processing Record 29 of Set 4 | guerrero negro
# Processing Record 30 of Set 4 | cherskiy
# Processing Record 31 of Set 4 | ranong
# Processing Record 32 of Set 4 | kargil
# Processing Record 33 of Set 4 | geresk
# City not found. Skipping...
# Processing Record 34 of Set 4 | naze
# Processing Record 35 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 4 | asau
# Processing Record 37 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 38 of Set 4 | beringovskiy
# Processing Record 39 of Set 4 | vao
# Processing Record 40 of Set 4 | adrar
# Processing Record 41 of Set 4 | graham
# Processing Record 42 of Set 4 | norfolk
# Processing Record 43 of Set 4 | severo-kurilsk
# Processing Record 44 of Set 4 | meulaboh
# Processing Record 45 of Set 4 | hamadan
# Processing Record 46 of Set 4 | pisco
# Processing Record 47 of Set 4 | sao joao da barra
# Processing Record 48 of Set 4 | la cruz
# Processing Record 49 of Set 4 | mecca
# Processing Record 50 of Set 4 | waipawa
# Processing Record 1 of Set 5 | calabozo
# Processing Record 2 of Set 5 | klaksvik
# Processing Record 3 of Set 5 | port elizabeth
# Processing Record 4 of Set 5 | lebanon
# Processing Record 5 of Set 5 | at-bashi
# Processing Record 6 of Set 5 | talara
# Processing Record 7 of Set 5 | ponta do sol
# Processing Record 8 of Set 5 | coihueco
# Processing Record 9 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 5 | havre-saint-pierre
# Processing Record 11 of Set 5 | ancud
# Processing Record 12 of Set 5 | ixtapa
# Processing Record 13 of Set 5 | pevek
# Processing Record 14 of Set 5 | san patricio
# Processing Record 15 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 16 of Set 5 | oranjemund
# Processing Record 17 of Set 5 | lermontovka
# Processing Record 18 of Set 5 | bocaranga
# City not found. Skipping...
# Processing Record 19 of Set 5 | dwarka
# Processing Record 20 of Set 5 | khorixas
# Processing Record 21 of Set 5 | moron
# Processing Record 22 of Set 5 | broome
# Processing Record 23 of Set 5 | provideniya
# Processing Record 24 of Set 5 | kantabanji
# Processing Record 25 of Set 5 | tarko-sale
# Processing Record 26 of Set 5 | maniitsoq
# Processing Record 27 of Set 5 | thunder bay
# Processing Record 28 of Set 5 | moranbah
# Processing Record 29 of Set 5 | correia pinto
# Processing Record 30 of Set 5 | andenes
# Processing Record 31 of Set 5 | deputatskiy
# Processing Record 32 of Set 5 | tumut
# Processing Record 33 of Set 5 | masterton
# Processing Record 34 of Set 5 | foumban
# Processing Record 35 of Set 5 | kawalu
# Processing Record 36 of Set 5 | kununurra
# Processing Record 37 of Set 5 | selfoss
# Processing Record 38 of Set 5 | sitka
# Processing Record 39 of Set 5 | qandahar
# City not found. Skipping...
# Processing Record 40 of Set 5 | tautira
# Processing Record 41 of Set 5 | kolno
# Processing Record 42 of Set 5 | te anau
# Processing Record 43 of Set 5 | buin
# Processing Record 44 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 45 of Set 5 | fortuna
# Processing Record 46 of Set 5 | sabha
# Processing Record 47 of Set 5 | banda
# Processing Record 48 of Set 5 | charters towers
# Processing Record 49 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 5 | college station
# Processing Record 1 of Set 6 | formosa
# Processing Record 2 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 3 of Set 6 | kloulklubed
# Processing Record 4 of Set 6 | sakakah
# Processing Record 5 of Set 6 | suntar
# Processing Record 6 of Set 6 | lamu
# Processing Record 7 of Set 6 | dire
# Processing Record 8 of Set 6 | naron
# Processing Record 9 of Set 6 | berlevag
# Processing Record 10 of Set 6 | riverton
# Processing Record 11 of Set 6 | praia
# Processing Record 12 of Set 6 | sitrah
# Processing Record 13 of Set 6 | bilma
# Processing Record 14 of Set 6 | olyka
# Processing Record 15 of Set 6 | bogorodskoye
# Processing Record 16 of Set 6 | usinsk
# Processing Record 17 of Set 6 | matara
# Processing Record 18 of Set 6 | norman wells
# Processing Record 19 of Set 6 | korla
# Processing Record 20 of Set 6 | kropotkin
# Processing Record 21 of Set 6 | buchanan
# Processing Record 22 of Set 6 | husavik
# Processing Record 23 of Set 6 | majene
# Processing Record 24 of Set 6 | barcelona
# Processing Record 25 of Set 6 | veselynove
# Processing Record 26 of Set 6 | geraldton
# Processing Record 27 of Set 6 | broken hill
# Processing Record 28 of Set 6 | kabanjahe
# Processing Record 29 of Set 6 | burnie
# Processing Record 30 of Set 6 | sur
# Processing Record 31 of Set 6 | sehithwa
# Processing Record 32 of Set 6 | faanui
# Processing Record 33 of Set 6 | bathsheba
# Processing Record 34 of Set 6 | sembakung
# Processing Record 35 of Set 6 | borogontsy
# Processing Record 36 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 6 | khasan
# Processing Record 38 of Set 6 | meiktila
# Processing Record 39 of Set 6 | aitape
# Processing Record 40 of Set 6 | gravdal
# Processing Record 41 of Set 6 | launceston
# Processing Record 42 of Set 6 | xinan
# Processing Record 43 of Set 6 | talnakh
# Processing Record 44 of Set 6 | cordoba
# Processing Record 45 of Set 6 | ati
# Processing Record 46 of Set 6 | villa carlos paz
# Processing Record 47 of Set 6 | vieste
# Processing Record 48 of Set 6 | komsomolskiy
# Processing Record 49 of Set 6 | longyearbyen
# Processing Record 50 of Set 6 | pestravka
# Processing Record 1 of Set 7 | kenai
# Processing Record 2 of Set 7 | dingle
# Processing Record 3 of Set 7 | muyezerskiy
# Processing Record 4 of Set 7 | moose factory
# Processing Record 5 of Set 7 | olaine
# Processing Record 6 of Set 7 | florida
# Processing Record 7 of Set 7 | sao lourenco do oeste
# Processing Record 8 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 9 of Set 7 | sibolga
# Processing Record 10 of Set 7 | novoagansk
# Processing Record 11 of Set 7 | sioux lookout
# Processing Record 12 of Set 7 | punta de bombon
# Processing Record 13 of Set 7 | northam
# Processing Record 14 of Set 7 | awjilah
# Processing Record 15 of Set 7 | dieppe
# Processing Record 16 of Set 7 | akonolinga
# Processing Record 17 of Set 7 | chara
# Processing Record 18 of Set 7 | esperance
# Processing Record 19 of Set 7 | necochea
# Processing Record 20 of Set 7 | tornio
# Processing Record 21 of Set 7 | aswan
# Processing Record 22 of Set 7 | katsuura
# Processing Record 23 of Set 7 | rameswaram
# Processing Record 24 of Set 7 | clearwater
# Processing Record 25 of Set 7 | anshun
# Processing Record 26 of Set 7 | harper
# Processing Record 27 of Set 7 | lebu
# Processing Record 28 of Set 7 | canico
# Processing Record 29 of Set 7 | dunedin
# Processing Record 30 of Set 7 | maues
# Processing Record 31 of Set 7 | alice springs
# Processing Record 32 of Set 7 | torbay
# Processing Record 33 of Set 7 | umm lajj
# Processing Record 34 of Set 7 | port-gentil
# Processing Record 35 of Set 7 | kruisfontein
# Processing Record 36 of Set 7 | pangnirtung
# Processing Record 37 of Set 7 | mount gambier
# Processing Record 38 of Set 7 | hrebinka
# Processing Record 39 of Set 7 | takaungu
# Processing Record 40 of Set 7 | moerai
# Processing Record 41 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 42 of Set 7 | eyrarbakki
# Processing Record 43 of Set 7 | guajara-mirim
# City not found. Skipping...
# Processing Record 44 of Set 7 | bengkulu
# Processing Record 45 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 7 | hangu
# Processing Record 47 of Set 7 | emmett
# Processing Record 48 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 7 | ust-kuyga
# Processing Record 50 of Set 7 | seoul
# Processing Record 1 of Set 8 | chicama
# Processing Record 2 of Set 8 | honningsvag
# Processing Record 3 of Set 8 | lere
# Processing Record 4 of Set 8 | noumea
# Processing Record 5 of Set 8 | luanda
# Processing Record 6 of Set 8 | nanortalik
# Processing Record 7 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 8 | maur
# Processing Record 9 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 8 | jawhar
# Processing Record 11 of Set 8 | pecos
# Processing Record 12 of Set 8 | iranshahr
# Processing Record 13 of Set 8 | sorgun
# Processing Record 14 of Set 8 | mhlume
# Processing Record 15 of Set 8 | marzuq
# Processing Record 16 of Set 8 | araouane
# Processing Record 17 of Set 8 | soubre
# Processing Record 18 of Set 8 | yeppoon
# Processing Record 19 of Set 8 | sambava
# Processing Record 20 of Set 8 | cooma
# Processing Record 21 of Set 8 | maldonado
# Processing Record 22 of Set 8 | havelock
# Processing Record 23 of Set 8 | brigantine
# Processing Record 24 of Set 8 | saint anthony
# Processing Record 25 of Set 8 | brae
# Processing Record 26 of Set 8 | pringsewu
# Processing Record 27 of Set 8 | pontianak
# Processing Record 28 of Set 8 | ketchenery
# City not found. Skipping...
# Processing Record 29 of Set 8 | cam ranh
# Processing Record 30 of Set 8 | ivdel
# Processing Record 31 of Set 8 | henties bay
# Processing Record 32 of Set 8 | siniscola
# Processing Record 33 of Set 8 | contai
# Processing Record 34 of Set 8 | port said
# Processing Record 35 of Set 8 | uyuni
# Processing Record 36 of Set 8 | palmer
# Processing Record 37 of Set 8 | yangambi
# Processing Record 38 of Set 8 | codrington
# Processing Record 39 of Set 8 | bella union
# Processing Record 40 of Set 8 | edd
# Processing Record 41 of Set 8 | saint-denis
# Processing Record 42 of Set 8 | bay roberts
# Processing Record 43 of Set 8 | tagusao
# Processing Record 44 of Set 8 | bandipur
# Processing Record 45 of Set 8 | comodoro rivadavia
# Processing Record 46 of Set 8 | aurora
# Processing Record 47 of Set 8 | saint albans
# Processing Record 48 of Set 8 | sanary-sur-mer
# Processing Record 49 of Set 8 | giresun
# Processing Record 50 of Set 8 | vardo
# Processing Record 1 of Set 9 | talakan
# Processing Record 2 of Set 9 | narasannapeta
# Processing Record 3 of Set 9 | zhigansk
# Processing Record 4 of Set 9 | leno
# Processing Record 5 of Set 9 | ngama
# Processing Record 6 of Set 9 | ornskoldsvik
# Processing Record 7 of Set 9 | svarstad
# Processing Record 8 of Set 9 | puerto del rosario
# Processing Record 9 of Set 9 | trapani
# Processing Record 10 of Set 9 | lubumbashi
# Processing Record 11 of Set 9 | hamilton
# Processing Record 12 of Set 9 | piacabucu
# Processing Record 13 of Set 9 | ostrovnoy
# Processing Record 14 of Set 9 | ayagoz
# Processing Record 15 of Set 9 | constitucion
# Processing Record 16 of Set 9 | valparaiso
# Processing Record 17 of Set 9 | barra dos coqueiros
# Processing Record 18 of Set 9 | sangmelima
# Processing Record 19 of Set 9 | altamirano
# Processing Record 20 of Set 9 | diglur
# Processing Record 21 of Set 9 | dunmore town
# Processing Record 22 of Set 9 | tura
# Processing Record 23 of Set 9 | altay
# Processing Record 24 of Set 9 | biltine
# Processing Record 25 of Set 9 | kizhinga
# Processing Record 26 of Set 9 | christchurch
# Processing Record 27 of Set 9 | altea
# Processing Record 28 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 9 | durango
# Processing Record 30 of Set 9 | conceicao do coite
# Processing Record 31 of Set 9 | catamarca
# Processing Record 32 of Set 9 | ratlam
# Processing Record 33 of Set 9 | baghdad
# Processing Record 34 of Set 9 | tarana
# Processing Record 35 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 9 | polunochnoye
# Processing Record 37 of Set 9 | kokopo
# Processing Record 38 of Set 9 | mandalgarh
# Processing Record 39 of Set 9 | staryy nadym
# Processing Record 40 of Set 9 | kazanskoye
# Processing Record 41 of Set 9 | limoeiro do ajuru
# Processing Record 42 of Set 9 | puerto quijarro
# Processing Record 43 of Set 9 | pedernales
# Processing Record 44 of Set 9 | vostok
# Processing Record 45 of Set 9 | bandarbeyla
# Processing Record 46 of Set 9 | itapora
# Processing Record 47 of Set 9 | ndele
# Processing Record 48 of Set 9 | puerto baquerizo moreno
# Processing Record 49 of Set 9 | mayahi
# Processing Record 50 of Set 9 | skotina
# Processing Record 1 of Set 10 | yulara
# Processing Record 2 of Set 10 | kilindoni
# Processing Record 3 of Set 10 | uvarovo
# Processing Record 4 of Set 10 | blackwater
# Processing Record 5 of Set 10 | barra do garcas
# Processing Record 6 of Set 10 | vila velha
# Processing Record 7 of Set 10 | hare bay
# Processing Record 8 of Set 10 | belorechensk
# Processing Record 9 of Set 10 | manado
# Processing Record 10 of Set 10 | kirgiz-miyaki
# Processing Record 11 of Set 10 | nioro
# Processing Record 12 of Set 10 | lompoc
# Processing Record 13 of Set 10 | sobolevo
# Processing Record 14 of Set 10 | burgersdorp
# Processing Record 15 of Set 10 | sabang
# Processing Record 16 of Set 10 | bonthe
# Processing Record 17 of Set 10 | buinsk
# Processing Record 18 of Set 10 | gizo
# Processing Record 19 of Set 10 | cedral
# Processing Record 20 of Set 10 | kingisepp
# Processing Record 21 of Set 10 | lichtenburg
# Processing Record 22 of Set 10 | aksu
# Processing Record 23 of Set 10 | debre zeyit
# Processing Record 24 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 25 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 10 | do rud
# City not found. Skipping...
# Processing Record 27 of Set 10 | khuzdar
# Processing Record 28 of Set 10 | severodvinsk
# Processing Record 29 of Set 10 | chulman
# Processing Record 30 of Set 10 | neryungri
# Processing Record 31 of Set 10 | huanren
# Processing Record 32 of Set 10 | suhbaatar
# Processing Record 33 of Set 10 | afgoye
# City not found. Skipping...
# Processing Record 34 of Set 10 | qaqortoq
# Processing Record 35 of Set 10 | biak
# Processing Record 36 of Set 10 | atar
# Processing Record 37 of Set 10 | svetlyy
# Processing Record 38 of Set 10 | carauari
# Processing Record 39 of Set 10 | weyburn
# Processing Record 40 of Set 10 | sistranda
# Processing Record 41 of Set 10 | jiexiu
# Processing Record 42 of Set 10 | shitanjing
# Processing Record 43 of Set 10 | meihekou
# Processing Record 44 of Set 10 | cabo san lucas
# Processing Record 45 of Set 10 | cabatuan
# Processing Record 46 of Set 10 | maceio
# Processing Record 47 of Set 10 | igarka
# Processing Record 48 of Set 10 | zastron
# Processing Record 49 of Set 10 | namibe
# Processing Record 50 of Set 10 | douentza
# Processing Record 1 of Set 11 | nurota
# Processing Record 2 of Set 11 | ahipara
# Processing Record 3 of Set 11 | laizhou
# Processing Record 4 of Set 11 | divnomorskoye
# Processing Record 5 of Set 11 | jand
# Processing Record 6 of Set 11 | san ramon de la nueva oran
# Processing Record 7 of Set 11 | cassilandia
# Processing Record 8 of Set 11 | deniliquin
# Processing Record 9 of Set 11 | ludvika
# Processing Record 10 of Set 11 | isangel
# Processing Record 11 of Set 11 | margate
# Processing Record 12 of Set 11 | gillette
# Processing Record 13 of Set 11 | ust-tsilma
# Processing Record 14 of Set 11 | lata
# Processing Record 15 of Set 11 | qasigiannguit
# Processing Record 16 of Set 11 | ormara
# Processing Record 17 of Set 11 | gushikawa
# Processing Record 18 of Set 11 | hammerfest
# Processing Record 19 of Set 11 | narsaq
# Processing Record 20 of Set 11 | strezhevoy
# Processing Record 21 of Set 11 | villa sandino
# Processing Record 22 of Set 11 | bongandanga
# Processing Record 23 of Set 11 | siteki
# Processing Record 24 of Set 11 | grindavik
# Processing Record 25 of Set 11 | alcains
# Processing Record 26 of Set 11 | boda
# Processing Record 27 of Set 11 | lagoa
# Processing Record 28 of Set 11 | paamiut
# Processing Record 29 of Set 11 | betioky
# Processing Record 30 of Set 11 | makakilo city
# Processing Record 31 of Set 11 | olafsvik
# Processing Record 32 of Set 11 | batemans bay
# Processing Record 33 of Set 11 | himora
# City not found. Skipping...
# Processing Record 34 of Set 11 | manokwari
# Processing Record 35 of Set 11 | lorut
# Processing Record 36 of Set 11 | fare
# Processing Record 37 of Set 11 | riviere-au-renard
# Processing Record 38 of Set 11 | oktyabrskoye
# Processing Record 39 of Set 11 | chadan
# Processing Record 40 of Set 11 | vanimo
# Processing Record 41 of Set 11 | hami
# Processing Record 42 of Set 11 | okha
# Processing Record 43 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 44 of Set 11 | gaimersheim
# Processing Record 45 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 11 | misratah
# Processing Record 47 of Set 11 | vestmannaeyjar
# Processing Record 48 of Set 11 | katangli
# Processing Record 49 of Set 11 | tual
# Processing Record 50 of Set 11 | taltal
# Processing Record 1 of Set 12 | hirara
# Processing Record 2 of Set 12 | bakel
# Processing Record 3 of Set 12 | nouadhibou
# Processing Record 4 of Set 12 | bonnyville
# Processing Record 5 of Set 12 | odweyne
# Processing Record 6 of Set 12 | knysna
# Processing Record 7 of Set 12 | gazanjyk
# Processing Record 8 of Set 12 | invermere
# Processing Record 9 of Set 12 | port moresby
# Processing Record 10 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 12 of Set 12 | santa fe
# Processing Record 13 of Set 12 | mukhen
# Processing Record 14 of Set 12 | hobyo
# Processing Record 15 of Set 12 | port keats
# Processing Record 16 of Set 12 | dawei
# Processing Record 17 of Set 12 | xinzhou
# Processing Record 18 of Set 12 | srednyaya yelyuzan
# Processing Record 19 of Set 12 | manggar
# Processing Record 20 of Set 12 | ewa beach
# Processing Record 21 of Set 12 | pavino
# Processing Record 22 of Set 12 | aybak
# City not found. Skipping...
# Processing Record 23 of Set 12 | canberra
# Processing Record 24 of Set 12 | kudahuvadhoo
# Processing Record 25 of Set 12 | morro bay
# Processing Record 26 of Set 12 | kirakira
# Processing Record 27 of Set 12 | carutapera
# Processing Record 28 of Set 12 | fairbanks
# Processing Record 29 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 30 of Set 12 | sorland
# Processing Record 31 of Set 12 | kaeo
# Processing Record 32 of Set 12 | portland
# Processing Record 33 of Set 12 | xiongshi
# City not found. Skipping...
# Processing Record 34 of Set 12 | les cayes
# Processing Record 35 of Set 12 | bratsk
# Processing Record 36 of Set 12 | cockburn town
# Processing Record 37 of Set 12 | bazarnyye mataki
# Processing Record 38 of Set 12 | loknya
# Processing Record 39 of Set 12 | vallenar
# Processing Record 40 of Set 12 | dehloran
# Processing Record 41 of Set 12 | monrovia
# Processing Record 42 of Set 12 | montepuez
# Processing Record 43 of Set 12 | ugoofaaru
# Processing Record 44 of Set 12 | pokhara
# Processing Record 45 of Set 12 | rio gallegos
# Processing Record 46 of Set 12 | kofele
# Processing Record 47 of Set 12 | airai
# Processing Record 48 of Set 12 | port lincoln
# Processing Record 49 of Set 12 | montes claros
# Processing Record 50 of Set 12 | arya
# Processing Record 1 of Set 13 | vangaindrano
# Processing Record 2 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 3 of Set 13 | buraydah
# Processing Record 4 of Set 13 | praia da vitoria
# Processing Record 5 of Set 13 | jubbal
# Processing Record 6 of Set 13 | coquimbo
# Processing Record 7 of Set 13 | skelleftea
# Processing Record 8 of Set 13 | doka
# Processing Record 9 of Set 13 | kita
# Processing Record 10 of Set 13 | ulaangom
# Processing Record 11 of Set 13 | the valley
# Processing Record 12 of Set 13 | rancho palos verdes
# Processing Record 13 of Set 13 | olinda
# Processing Record 14 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 15 of Set 13 | zhezkazgan
# Processing Record 16 of Set 13 | lasa
# Processing Record 17 of Set 13 | oloron-sainte-marie
# Processing Record 18 of Set 13 | san juan
# Processing Record 19 of Set 13 | tabou
# Processing Record 20 of Set 13 | sayanskiy
# City not found. Skipping...
# Processing Record 21 of Set 13 | cacule
# Processing Record 22 of Set 13 | rypin
# Processing Record 23 of Set 13 | padang
# Processing Record 24 of Set 13 | ekhabi
# Processing Record 25 of Set 13 | lorengau
# Processing Record 26 of Set 13 | namatanai
# Processing Record 27 of Set 13 | koster
# Processing Record 28 of Set 13 | mbekenyera
# Processing Record 29 of Set 13 | acarau
# Processing Record 30 of Set 13 | fukuma
# Processing Record 31 of Set 13 | arlit
# Processing Record 32 of Set 13 | muros
# Processing Record 33 of Set 13 | atambua
# Processing Record 34 of Set 13 | belgrade
# Processing Record 35 of Set 13 | la palma
# Processing Record 36 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 37 of Set 13 | keti bandar
# Processing Record 38 of Set 13 | ofunato
# Processing Record 39 of Set 13 | hokitika
# Processing Record 40 of Set 13 | pouebo
# Processing Record 41 of Set 13 | montevideo
# Processing Record 42 of Set 13 | san ramon
# Processing Record 43 of Set 13 | taoudenni
# Processing Record 44 of Set 13 | arkhangelsk
# Processing Record 45 of Set 13 | piranshahr
# Processing Record 46 of Set 13 | vestmanna
# Processing Record 47 of Set 13 | katherine
# Processing Record 48 of Set 13 | hoquiam
# Processing Record 49 of Set 13 | fougamou
# Processing Record 50 of Set 13 | port blair

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 0

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
# Out:
#   File "C:\Users\16187\AppData\Local\Temp\ipykernel_35088\1173080176.py", line 2
#     city_data_df = # YOUR CODE HERE
#                                    ^
# SyntaxError: invalid syntax

# %%
# Display sample data
city_data_df.head(10)

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
 new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file,index=False)
